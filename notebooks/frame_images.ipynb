# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd

# %%
r1 = pd.read_csv('../processed/manually_labeled_dataset.csv')
r2 = pd.read_csv('../processed/manual_labeled_dataset2.csv')
labeled_df = pd.read_csv('../processed/.csv')

# %%
labeled_plays = labeled_df["play_id"].unique()

for pid in labeled_plays:
    generate_frames_for_play(tracking_df, pid)
